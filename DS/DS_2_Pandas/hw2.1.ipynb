# %%
import pandas as pd
import numpy as np

# %%
link = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C"

# %%
data = pd.read_html(link, thousands='.', decimal = ',')[10]

# %%
print(data.head())
# Out:
#              Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0              Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1         Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2         Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3  Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4          Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —

# %%
print(data.shape)
# Out:
# (28, 9)

# %%
data.replace(to_replace = "—", value = np.nan, inplace=True)
print(data)
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %%
data.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014       object
# 2019       object
# dtype: object

# %%
data = data.astype("float32", errors='ignore')
data.dtypes
# Out:
# Регіон     object
# 1950      float32
# 1960      float32
# 1970      float32
# 1990      float32
# 2000      float32
# 2012      float32
# 2014      float32
# 2019      float32
# dtype: object

# %%
pd.isnull(data).sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
data = data[:-1]
data
# Out:
#                Регіон       1950       1960       1970       1990  2000  2012  \
# 0                Крим  23.000000  20.600000  16.000000  13.000000   7.3  12.6
# 1           Вінницька  22.400000  19.200001  14.200000  12.400000   8.4  11.2
# 2           Волинська  24.700001  25.000000  17.900000  15.300000  11.2  14.8
# 3    Дніпропетровська  20.400000  20.400000  15.100000  12.300000   7.1  11.2
# 4            Донецька  27.100000  21.400000  14.000000  10.900000   6.1   9.8
# 5         Житомирська  26.100000  22.299999  15.900000  12.900000   8.9  12.2
# 6        Закарпатська  31.400000  27.299999  20.700001  16.799999  11.5  15.1
# 7          Запорізька  21.900000  19.700001  15.000000  12.400000   7.1  10.6
# 8   Івано-Франківська  24.299999  24.799999  18.200001  15.500000  10.3  12.4
# 9            Київська  20.400000  18.900000  15.600000  12.300000   7.3  12.2
# 10     Кіровоградська  21.600000  17.100000  14.500000  12.600000   7.9  11.0
# ...

# %%
data = data.fillna(data.mean(numeric_only=True))
data
# Out:
#                Регіон       1950       1960       1970       1990  2000  2012  \
# 0                Крим  23.000000  20.600000  16.000000  13.000000   7.3  12.6
# 1           Вінницька  22.400000  19.200001  14.200000  12.400000   8.4  11.2
# 2           Волинська  24.700001  25.000000  17.900000  15.300000  11.2  14.8
# 3    Дніпропетровська  20.400000  20.400000  15.100000  12.300000   7.1  11.2
# 4            Донецька  27.100000  21.400000  14.000000  10.900000   6.1   9.8
# 5         Житомирська  26.100000  22.299999  15.900000  12.900000   8.9  12.2
# 6        Закарпатська  31.400000  27.299999  20.700001  16.799999  11.5  15.1
# 7          Запорізька  21.900000  19.700001  15.000000  12.400000   7.1  10.6
# 8   Івано-Франківська  24.299999  24.799999  18.200001  15.500000  10.3  12.4
# 9            Київська  20.400000  18.900000  15.600000  12.300000   7.3  12.2
# 10     Кіровоградська  21.600000  17.100000  14.500000  12.600000   7.9  11.0
# ...

# %%
ndf = data[data['2019'] > data['2019'].mean()]
ndf[['Регіон', '2019']]
# Out:
#                Регіон  2019
# 2           Волинська  10.1
# 6        Закарпатська  10.4
# 8   Івано-Франківська   8.8
# 12          Львівська   8.7
# 14            Одеська   8.8
# 16         Рівненська  10.7
# 20         Херсонська   8.1
# 23        Чернівецька   9.2
# 25               Київ  11.0

# %%
data[data['2014'] == data['2014'].max()]['Регіон']
# Out:
# 16    Рівненська
# Name: Регіон, dtype: object

# %%
data['2019'].plot(kind='bar')
